# %%
#https://trade.shoonya.com/#/
#password: RAJU@88raj
#New Password: RAJ@88raju on 17 April 2024

# %%
from NorenRestApiPy.NorenApi import  NorenApi
#from threading import Timer
import time
import logging
import pyotp



api = None

#Function for time cal
##################################################################################
def get_time(time_string):
    data = time.strptime(time_string,'%d-%m-%Y %H:%M:%S')

    return time.mktime(data)
##################################################################################

class ShoonyaApiPy(NorenApi):
    def __init__(self):
        NorenApi.__init__(self, host='https://api.shoonya.com/NorenWClientTP/', websocket='wss://api.shoonya.com/NorenWSTP/')        


#enable dbug to see request and responses
logging.basicConfig(level=logging.DEBUG)

#start of our program
api = ShoonyaApiPy()

#credentials
##################### Prism Password = Rajraj@88
##################### Shoonya Password = Rajraj@88  ########## both are same

token = '57DF444TKFWU347YY55N44IRGMALZXA2' 
user    = 'FA25376'
pwd     = 'RAJ@88raju'
factor2 = pyotp.TOTP(token).now()
vc      = 'FA25376_U'
app_key = '7f0dca9da87909a1bc35373f68162d42'
imei    = 'abc1234'

#make the api call
ret = api.login(userid=user, password=pwd, twoFA=factor2, vendor_code=vc, api_secret=app_key, imei=imei)

print(ret)
# Out:
# DEBUG:NorenRestApiPy.NorenApi:https://api.shoonya.com/NorenWClientTP//QuickAuth
# DEBUG:NorenRestApiPy.NorenApi:Req:jData={"source": "API", "apkversion": "1.0.0", "uid": "FA25376", "pwd": "01d891e3ca9a5c22dc5710c55f62fb0c5ed66544edb9818362264886b4bd286f", "factor2": "043945", "vc": "FA25376_U", "appkey": "bc069f28741d739992e488e3c24ac5ad462c62bc79de8d1d3e970fd0fe685978", "imei": "abc1234"}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.shoonya.com:443
# DEBUG:urllib3.connectionpool:https://api.shoonya.com:443 "POST /NorenWClientTP//QuickAuth HTTP/1.1" 200 870
# ...

# %%
import pandas as pd
date_range = pd.bdate_range(start = '05-01-2023', end = '05-12-2023',freq ='C',holidays = holidays(2023))

# %%
date_range
# Out:
# DatetimeIndex(['2023-05-02', '2023-05-03', '2023-05-04', '2023-05-05',
#                '2023-05-08', '2023-05-09', '2023-05-10', '2023-05-11',
#                '2023-05-12'],
#               dtype='datetime64[ns]', freq='C')

# %%
#Function for time cal
##################################################################################
def get_time(time_string):
    data = time.strptime(time_string,'%Y-%m-%d %H:%M:%S')

    return time.mktime(data)
##################################################################################df['mydate'].dt.strftime('%Y%m%d')

# %%
for date in date_range:
    print(str(date))
    
    break
# Out:
# Timestamp('2023-05-02 00:00:00', freq='C')

# %%
str(date)
# Out:
# '2023-05-02 00:00:00'

# %%
get_time(str(date))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-63c1ad4a6909> in <module>
# ----> 1 get_time(str(date))
#
# <ipython-input-22-2d57ac1a82c7> in get_time(time_string)
#       2 ##################################################################################
#       3 def get_time(time_string):
# ----> 4     data = time.strptime(time_string,'%Y-%m-%d %H:%M:%S')
#       5
#       6     return time.mktime(data)
#
# AttributeError: type object 'datetime.time' has no attribute 'strptime'

# %%
date_range
# Out:
# DatetimeIndex(['2023-05-02', '2023-05-03', '2023-05-04', '2023-05-05',
#                '2023-05-08', '2023-05-09', '2023-05-10', '2023-05-11',
#                '2023-05-12'],
#               dtype='datetime64[ns]', freq='C')

# %%
import pandas as pd

token_file_name = ['reliance_token_may.txt'] # ,'fn_token20-4-2023.txt' 'nifty_token20-4-2023.txt','bn_token20-4-2023.txt' 

#["05-05-2023 00:00:00","05-05-2023 15:30:00"]
#["02-05-2023 00:00:00","02-05-2023 15:30:00"],["03-05-2023 00:00:00","03-05-2023 15:30:00"],["04-05-2023 00:00:00","04-05-2023 15:30:00"],
date_list = [["02-05-2023 00:00:00","02-05-2023 15:30:00"],["03-05-2023 00:00:00","03-05-2023 15:30:00"],["04-05-2023 00:00:00","04-05-2023 15:30:00"],["08-05-2023 00:00:00","08-05-2023 15:30:00"],["09-05-2023 00:00:00","09-05-2023 15:30:00"],["10-05-2023 00:00:00","10-05-2023 15:30:00"],["12-05-2023 00:00:00","12-05-2023 15:30:00"]]


for files in token_file_name:
    
    req_token = pd.read_csv(files)
    #break
    for date in date_list:
        print(date)
        start_time = get_time(date[0])
        end_time = get_time(date[1])
        print(start_time)
        print(end_time)
        #break
    #break    
        final_df = pd.DataFrame()
        token_list = list(req_token['Token'])
        for token in token_list:
            #print(token)
            ret = api.get_time_price_series(exchange='NFO', token=str(token), starttime=start_time, endtime=end_time, interval=1)

            df = pd.DataFrame.from_dict(ret)
            #print(df)  

            if df.empty == True:
                pass
            else:

                #Spliting date and time into saperate columns
                df.rename(columns = {'time':'datetime','into':'open','inth':'high','intl':'low','intc':'close'},inplace=True)
                df['date'] = df['datetime'].apply(lambda x:x.split(" ")[0])
                df['time'] = df['datetime'].apply(lambda x:x.split(" ")[1])

                df['symbol']         = req_token[req_token['Token']==token]['Symbol'].iloc[0]
                df['trading_symbol'] = req_token[req_token['Token']==token]['TradingSymbol'].iloc[0]
                df['exp_date']       = req_token[req_token['Token']==token]['Expiry'].iloc[0]
                df['option_type']    = req_token[req_token['Token']==token]['OptionType'].iloc[0]
                df['strike_price']   = req_token[req_token['Token']==token]['StrikePrice'].iloc[0]
                df['instrument']     = req_token[req_token['Token']==token]['Instrument'].iloc[0]

                df = df[['symbol','date','time','trading_symbol','exp_date','option_type','instrument','strike_price','open','high','low','close','intvwap','intv','intoi','v','oi','ssboe','stat']]
                final_df = final_df.append(df)
            #break
        filename = req_token['Symbol'].iloc[0] + '_' + final_df['date'].iloc[0] + '.csv'
        final_df.to_csv('E:/Finvesiya_data_day_wise/' + filename, header=True,index = False )
        #break

# %%
final_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
start_time = get_time("01-01-2021 00:00:00")
end_time = get_time("25-01-2024 15:30:00")
token = 4963

# %%
ret = api.get_time_price_series(exchange='NFO', token=str(token), starttime=start_time, endtime=end_time, interval=Day)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bc0eb7669582> in <module>
# ----> 1 ret = api.get_time_price_series(exchange='NFO', token=str(token), starttime=start_time, endtime=end_time, interval=Day)
#
# NameError: name 'api' is not defined

# %%
df = pd.DataFrame.from_dict(ret)

# %%
req_token[req_token['Token']==4963]['Instrument'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e9455213c4b2> in <module>
# ----> 1 req_token[req_token['Token']==4963]['Instrument'].iloc[0]
#
# NameError: name 'req_token' is not defined

# %%
req_token
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fdfbcc1cba97> in <module>
# ----> 1 req_token
#
# NameError: name 'req_token' is not defined

# %%
from jugaad_data.holidays import holidays
from datetime import time, date, datetime

"""
 Holiday list based on Zipline calendar library's holiday calendar
 Reference:    https://github.com/quantopian/trading_calendars/blob/master/trading_calendars/exchange_calendar_xbom.py
"""

holidays_str = [
    '1997-01-23',
    '1997-03-07',
    '1997-03-24',
    '1997-04-08',
    '1997-04-14',
    '1997-04-16',
    '1997-04-18',
    '1997-05-01',
    '1997-05-08',
    '1997-08-15',
    '1997-08-18',
    '1997-08-25',
    '1997-10-02',
    '1997-10-28',
    '1997-10-29',
    '1997-10-31',
    '1997-12-25',
    '1998-04-09',
    '1998-04-14',
    '1998-04-28',
    '1998-12-25',
    '1999-01-01',
    '1999-01-20',
    '1999-01-26',
    '1999-03-02',
    '1999-03-18',
    '1999-03-25',
    '1999-03-29',
    '1999-04-02',
    '1999-04-14',
    '1999-04-27',
    '1999-04-30',
    '1999-09-13',
    '1999-10-19',
    '1999-11-08',
    '1999-11-10',
    '1999-11-23',
    '1999-12-31',
    '2000-01-26',
    '2000-03-17',
    '2000-03-20',
    '2000-04-14',
    '2000-04-21',
    '2000-05-01',
    '2000-08-15',
    '2000-09-01',
    '2000-10-02',
    '2000-12-25',
    '2001-01-01',
    '2001-01-26',
    '2001-03-06',
    '2001-04-05',
    '2001-04-13',
    '2001-05-01',
    '2001-08-15',
    '2001-08-22',
    '2001-10-02',
    '2001-10-26',
    '2001-11-16',
    '2001-11-30',
    '2001-12-17',
    '2001-12-25',
    '2002-03-25',
    '2002-03-29',
    '2002-05-01',
    '2002-08-15',
    '2002-09-10',
    '2002-10-02',
    '2002-10-15',
    '2002-11-06',
    '2002-11-19',
    '2002-12-25',
    '2003-02-13',
    '2003-03-14',
    '2003-03-18',
    '2003-04-14',
    '2003-04-18',
    '2003-05-01',
    '2003-08-15',
    '2003-10-02',
    '2003-11-26',
    '2003-12-25',
    '2004-01-01',
    '2004-01-26',
    '2004-02-02',
    '2004-03-02',
    '2004-04-09',
    '2004-04-14',
    '2004-04-26',
    '2004-10-13',
    '2004-10-22',
    '2004-11-15',
    '2004-11-26',
    '2005-01-21',
    '2005-01-26',
    '2005-03-25',
    '2005-04-14',
    '2005-07-28',
    '2005-08-15',
    '2005-09-07',
    '2005-10-12',
    '2005-11-03',
    '2005-11-04',
    '2005-11-15',
    '2006-01-11',
    '2006-01-26',
    '2006-02-09',
    '2006-03-15',
    '2006-04-06',
    '2006-04-11',
    '2006-04-14',
    '2006-05-01',
    '2006-08-15',
    '2006-10-02',
    '2006-10-24',
    '2006-10-25',
    '2006-12-25',
    '2007-01-01',
    '2007-01-26',
    '2007-01-30',
    '2007-02-16',
    '2007-03-27',
    '2007-04-06',
    '2007-05-01',
    '2007-05-02',
    '2007-08-15',
    '2007-10-02',
    '2007-12-21',
    '2007-12-25',
    '2008-03-06',
    '2008-03-20',
    '2008-03-21',
    '2008-04-14',
    '2008-04-18',
    '2008-05-01',
    '2008-05-19',
    '2008-08-15',
    '2008-09-03',
    '2008-10-02',
    '2008-10-09',
    '2008-10-30',
    '2008-11-13',
    '2008-11-27',
    '2008-12-09',
    '2008-12-25',
    '2009-01-08',
    '2009-01-26',
    '2009-02-23',
    '2009-03-10',
    '2009-03-11',
    '2009-04-03',
    '2009-04-07',
    '2009-04-10',
    '2009-04-14',
    '2009-04-30',
    '2009-05-01',
    '2009-09-21',
    '2009-09-28',
    '2009-10-02',
    '2009-10-13',
    '2009-10-19',
    '2009-11-02',
    '2009-12-25',
    '2009-12-28',
    '2010-01-01',
    '2010-01-26',
    '2010-02-12',
    '2010-03-01',
    '2010-03-24',
    '2010-04-02',
    '2010-04-14',
    '2010-09-10',
    '2010-11-17',
    '2010-12-17',
    '2011-01-26',
    '2011-03-02',
    '2011-04-12',
    '2011-04-14',
    '2011-04-22',
    '2011-08-15',
    '2011-08-31',
    '2011-09-01',
    '2011-10-06',
    '2011-10-27',
    '2011-11-07',
    '2011-11-10',
    '2011-12-06',
    '2012-01-26',
    '2012-02-20',
    '2012-03-08',
    '2012-04-05',
    '2012-04-06',
    '2012-05-01',
    '2012-08-15',
    '2012-08-20',
    '2012-09-19',
    '2012-10-02',
    '2012-10-24',
    '2012-11-14',
    '2012-11-28',
    '2012-12-25',
    '2013-03-27',
    '2013-03-29',
    '2013-04-19',
    '2013-04-24',
    '2013-05-01',
    '2013-08-09',
    '2013-08-15',
    '2013-09-09',
    '2013-10-02',
    '2013-10-16',
    '2013-11-04',
    '2013-11-15',
    '2013-12-25',
    '2014-02-27',
    '2014-03-17',
    '2014-04-08',
    '2014-04-14',
    '2014-04-18',
    '2014-04-24',
    '2014-05-01',
    '2014-07-29',
    '2014-08-15',
    '2014-08-29',
    '2014-10-02',
    '2014-10-03',
    '2014-10-06',
    '2014-10-15',
    '2014-10-24',
    '2014-11-04',
    '2014-11-06',
    '2014-12-25',
    '2015-01-26',
    '2015-02-17',
    '2015-03-06',
    '2015-04-02',
    '2015-04-03',
    '2015-04-14',
    '2015-05-01',
    '2015-09-17',
    '2015-09-25',
    '2015-10-02',
    '2015-10-22',
    '2015-11-12',
    '2015-11-25',
    '2015-12-25',
    '2016-01-26',
    '2016-03-07',
    '2016-03-24',
    '2016-03-25',
    '2016-04-14',
    '2016-04-15',
    '2016-04-19',
    '2016-07-06',
    '2016-08-15',
    '2016-09-05',
    '2016-09-13',
    '2016-10-11',
    '2016-10-12',
    '2016-10-31',
    '2016-11-14',
    '2017-01-26',
    '2017-02-24',
    '2017-03-13',
    '2017-04-04',
    '2017-04-14',
    '2017-05-01',
    '2017-06-26',
    '2017-08-15',
    '2017-08-25',
    '2017-10-02',
    '2017-10-20',
    '2017-12-25',
    '2018-01-26',
    '2018-02-13',
    '2018-03-02',
    '2018-03-29',
    '2018-03-30',
    '2018-05-01',
    '2018-08-15',
    '2018-08-22',
    '2018-09-13',
    '2018-09-20',
    '2018-10-02',
    '2018-10-18',
    '2018-11-08',
    '2018-11-23',
    '2018-12-25',
    '2019-01-26',
    '2019-03-02',
    '2019-03-04',
    '2019-03-21',
    '2019-04-17',
    '2019-04-19',
    '2019-04-29',
    '2019-05-01',
    '2019-06-05',
    '2019-08-12',
    '2019-08-15',
    '2019-09-02',
    '2019-09-10',
    '2019-10-02',
    '2019-10-08',
    '2019-10-21',
    '2019-10-28',
    '2019-11-12',
    '2019-12-25',
    '2020-02-21',
    '2020-03-10',
    '2020-04-02',
    '2020-04-06',
    '2020-04-10',
    '2020-04-14',
    '2020-05-01',
    '2020-05-25',
    '2020-07-31',
    '2020-10-02',
    '2020-11-16',
    '2020-11-30',
    '2020-12-25',
    '2021-01-26',
    '2021-03-11',
    '2021-03-29',
    '2021-04-02',
    '2021-04-14',
    '2021-04-21',
    '2021-05-13',
    '2021-07-21',
    '2021-08-19',
    '2021-09-10',
    '2021-10-15',
    '2021-11-05',
    '2021-11-19',
    '2022-01-26',
    '2022-03-01',
    '2022-03-18',
    '2022-04-14',
    '2022-04-15',
    '2022-05-03',
    '2022-08-09',
    '2022-08-15',
    '2022-08-31',
    '2022-10-05',
    '2022-10-24',
    '2022-10-26',
    '2022-11-08',
    '2023-01-26',
    '2023-02-18', # weekend
    '2023-03-07',
    '2023-03-30',
    '2023-04-04',
    '2023-04-07',
    '2023-04-14',
    '2023-04-22', # weekend
    '2023-05-01',
    '2023-06-28',
    '2023-07-29', # weekend
    '2023-08-15',
    '2023-09-19',
    '2023-10-02',
    '2023-10-24',
    '2023-11-12', # weekend
    '2023-11-14',
    '2023-11-27',
    '2023-12-25'
    ]
#"%Y-%m-%d"

def holidays(year=None, month=None):
    h = [datetime.strptime(d, "%Y-%m-%d").date() for d in holidays_str]
    if year:
        h = [d for d in h if d.year==year]
    if month:
        h = [d for d in h if d.month==month]
    return h
